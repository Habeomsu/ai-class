# %%
# define and use the generator model
from numpy.random import randn
from keras.models import Sequential
from keras.layers import Dense
from matplotlib import pyplot
from tensorflow.keras.utils import plot_model

# define the standalone generator model
def define_generator(latent_dim, n_outputs=2):
	model = Sequential()
	model.add(Dense(15, activation='relu', kernel_initializer='he_uniform', input_dim=latent_dim))
	model.add(Dense(n_outputs, activation='linear'))
	return model

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n):
	# generate points in the latent space
	x_input = randn(latent_dim * n)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n, latent_dim)
	return x_input

# use the generator to generate n fake examples and plot the results
def generate_fake_samples(generator, latent_dim, n):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n)
	# predict outputs
	X = generator.predict(x_input)
	# plot the results
	pyplot.scatter(X[:, 0], X[:, 1])
	pyplot.show()

# size of the latent space
latent_dim = 5
# define the discriminator model
model = define_generator(latent_dim)
# generate and plot generated samples
generate_fake_samples(model, latent_dim, 100)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from numpy import hstack
from numpy import zeros
from numpy import ones
from numpy.random import rand
from numpy.random import randn
from keras.models import Sequential
from keras.layers import Dense
from matplotlib import pyplot

# %%
# define the standalone discriminator model
def define_discriminator(n_inputs=2):
	model = Sequential()
	model.add(Dense(25, activation='relu', kernel_initializer='he_uniform', input_dim=n_inputs))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model
 
# define the standalone generator model
def define_generator(latent_dim, n_outputs=2):
	model = Sequential()
	model.add(Dense(15, activation='relu', kernel_initializer='he_uniform', input_dim=latent_dim))
	model.add(Dense(n_outputs, activation='linear'))
	return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(generator, discriminator):
	# make weights in the discriminator not trainable
	discriminator.trainable = False
	# connect them
	model = Sequential()
	# add generator
	model.add(generator)
	# add the discriminator
	model.add(discriminator)
	# compile model
	model.compile(loss='binary_crossentropy', optimizer='adam')
	return model
 
# generate n real samples with class labels
def generate_real_samples(n):
	# generate inputs in [-0.5, 0.5]
	X1 = rand(n) - 0.5
	# generate outputs X^2
	X2 = X1 * X1
	# stack arrays
	X1 = X1.reshape(n, 1)
	X2 = X2.reshape(n, 1)
	X = hstack((X1, X2))
	# generate class labels
	y = ones((n, 1))
	return X, y
 
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n):
	# generate points in the latent space
	x_input = randn(latent_dim * n)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n, latent_dim)
	return x_input
 
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n)
	# predict outputs
	X = generator.predict(x_input)
	# create class labels
	y = zeros((n, 1))
	return X, y

# %%
# evaluate the discriminator and plot real and fake points
def summarize_performance(epoch, generator, discriminator, latent_dim, n=100):
	# prepare real samples
	x_real, y_real = generate_real_samples(n)
	# evaluate discriminator on real examples
	_, acc_real = discriminator.evaluate(x_real, y_real, verbose=0)
	# prepare fake examples
	x_fake, y_fake = generate_fake_samples(generator, latent_dim, n)
	# evaluate discriminator on fake examples
	_, acc_fake = discriminator.evaluate(x_fake, y_fake, verbose=0)
	
    # summarize discriminator performance
	print(epoch, acc_real, acc_fake)
	# scatter plot real and fake data points
	pyplot.scatter(x_real[:, 0], x_real[:, 1], color='red')
	pyplot.scatter(x_fake[:, 0], x_fake[:, 1], color='blue')
	pyplot.show()

# %%
# train the generator and discriminator
def train(g_model, d_model, gan_model, latent_dim, n_epochs=10000, n_batch=128, n_eval=2000):
	# determine half the size of one batch, for updating the discriminator
	half_batch = int(n_batch / 2)
	# manually enumerate epochs
	for i in range(n_epochs):
		# prepare real samples
		x_real, y_real = generate_real_samples(half_batch)
		# prepare fake examples
		x_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
		# update discriminator
		d_model.train_on_batch(x_real, y_real)
		d_model.train_on_batch(x_fake, y_fake)
		# prepare points in latent space as input for the generator
		x_gan = generate_latent_points(latent_dim, n_batch)
		# create inverted labels for the fake samples
		y_gan = ones((n_batch, 1))
		# update the generator via the discriminator's error
		gan_model.train_on_batch(x_gan, y_gan)
		# evaluate the model every n_eval epochs
		if (i+1) % n_eval == 0:
			summarize_performance(i, g_model, d_model, latent_dim)

# %%
# size of the latent space
latent_dim = 5
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# train model
train(generator, discriminator, gan_model, latent_dim)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x13f16bce0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x13f18fc40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 9999 0.9599999785423279 0.0
