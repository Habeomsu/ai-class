# %%
import numpy as np
def generate_real_samples(n):
    '''generate n real samples with class labels'''
    x1 = np.random.rand(n) - 0.5 #generate a random number between [-0.5,0.5]
    x2 = x1**3        #generate outputs
    x1 = x1.reshape(n, 1)
    x2 = x2.reshape(n, 1)
    X = np.hstack((x1, x2))   #stack layers
    y = np.ones((n, 1))     #generate class label
    return X,y

# %%
from keras.models import Sequential
from keras.layers import Dense, LeakyReLU
from keras.utils import plot_model
import matplotlib.pyplot as plt

def define_discriminator(inputs = 2):
    ''' function to return the compiled discriminator model'''
    model = Sequential()
    model.add(Dense(25, activation = 'relu', kernel_initializer = 'he_uniform', input_dim = inputs))
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Dense(15, activation = 'relu', kernel_initializer = 'he_uniform'))
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Dense(5, activation = 'relu', kernel_initializer = 'he_uniform'))
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

discriminator_model = define_discriminator()
discriminator_model.summary()
plot_model(discriminator_model, to_file = 'discriminator_model.png', show_shapes = True, show_layer_names = True)
# Out:
# /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 25)             │            75 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │           390 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 15)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 5)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 551 (2.15 KB)
#  Trainable params: 551 (2.15 KB)
#  Non-trainable params: 0 (0.00 B)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/pydot/core.py:1851, in Dot.create(self, prog, format, encoding)
#    1850 try:
# -> 1851     stdout_data, stderr_data, process = call_graphviz(
#    1852         program=prog,
#    1853         arguments=arguments,
#    1854         working_dir=tmp_dir,
#    1855     )
#    1856 except OSError as e:
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/pydot/core.py:211, in call_graphviz(program, arguments, working_dir, **kwargs)
#     209 program_with_args = [program] + arguments
# --> 211 process = subprocess.Popen(
#     212     program_with_args,
#     213     env=env,
#     214     cwd=working_dir,
#     215     shell=False,
#     216     stderr=subprocess.PIPE,
#     217     stdout=subprocess.PIPE,
#     218     **kwargs,
#     219 )
#     220 stdout_data, stderr_data = process.communicate()
#
# File /opt/anaconda3/envs/school/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /opt/anaconda3/envs/school/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:37, in check_graphviz()
#      34 try:
#      35     # Attempt to create an image of a blank graph
#      36     # to check the pydot/graphviz installation.
# ---> 37     pydot.Dot.create(pydot.Dot())
#      38     return True
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/pydot/core.py:1860, in Dot.create(self, prog, format, encoding)
#    1859     args[1] = f'"{prog}" not found in path.'
# -> 1860     raise OSError(*args)
#    1861 else:
#
# FileNotFoundError: [Errno 2] "dot" not found in path.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 21
#      19 discriminator_model = define_discriminator()
#      20 discriminator_model.summary()
# ---> 21 plot_model(discriminator_model, to_file = 'discriminator_model.png', show_shapes = True, show_layer_names = True)
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:430, in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, show_layer_activations, show_trainable, **kwargs)
#     428     else:
#     429         raise ImportError(message)
# --> 430 if not check_graphviz():
#     431     message = (
#     432         "You must install graphviz "
#     433         "(see instructions at https://graphviz.gitlab.io/download/) "
#     434         "for `plot_model` to work."
#     435     )
#     436     if "IPython.core.magics.namespace" in sys.modules:
#     437         # We don't raise an exception here in order to avoid crashing
#     438         # notebook tests where graphviz is not available.
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:39, in check_graphviz()
#      37     pydot.Dot.create(pydot.Dot())
#      38     return True
# ---> 39 except (OSError, pydot.InvocationException):
#      40     return False
#
# AttributeError: module 'pydot' has no attribute 'InvocationException'

# %%
def define_generator(latent_dim, outputs = 2):
    model = Sequential()
    model.add(Dense(25, activation = 'relu', kernel_initializer= 'he_uniform', input_dim = latent_dim))
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Dense(15, activation = 'relu', kernel_initializer = 'he_uniform'))
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Dense(outputs, activation = 'linear'))
    return model

# %%
latent_dim = 5
generator_model = define_generator(latent_dim)
generator_model.summary()
plot_model(generator_model, to_file = 'generator_model.png', show_shapes = True, show_layer_names = True)
# Out:
# /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 25)             │           150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 15)             │           390 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 15)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 2)              │            32 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 572 (2.23 KB)
#  Trainable params: 572 (2.23 KB)
#  Non-trainable params: 0 (0.00 B)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/pydot/core.py:1851, in Dot.create(self, prog, format, encoding)
#    1850 try:
# -> 1851     stdout_data, stderr_data, process = call_graphviz(
#    1852         program=prog,
#    1853         arguments=arguments,
#    1854         working_dir=tmp_dir,
#    1855     )
#    1856 except OSError as e:
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/pydot/core.py:211, in call_graphviz(program, arguments, working_dir, **kwargs)
#     209 program_with_args = [program] + arguments
# --> 211 process = subprocess.Popen(
#     212     program_with_args,
#     213     env=env,
#     214     cwd=working_dir,
#     215     shell=False,
#     216     stderr=subprocess.PIPE,
#     217     stdout=subprocess.PIPE,
#     218     **kwargs,
#     219 )
#     220 stdout_data, stderr_data = process.communicate()
#
# File /opt/anaconda3/envs/school/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /opt/anaconda3/envs/school/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:37, in check_graphviz()
#      34 try:
#      35     # Attempt to create an image of a blank graph
#      36     # to check the pydot/graphviz installation.
# ---> 37     pydot.Dot.create(pydot.Dot())
#      38     return True
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/pydot/core.py:1860, in Dot.create(self, prog, format, encoding)
#    1859     args[1] = f'"{prog}" not found in path.'
# -> 1860     raise OSError(*args)
#    1861 else:
#
# FileNotFoundError: [Errno 2] "dot" not found in path.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       2 generator_model = define_generator(latent_dim)
#       3 generator_model.summary()
# ----> 4 plot_model(generator_model, to_file = 'generator_model.png', show_shapes = True, show_layer_names = True)
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:430, in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, show_layer_activations, show_trainable, **kwargs)
#     428     else:
#     429         raise ImportError(message)
# --> 430 if not check_graphviz():
#     431     message = (
#     432         "You must install graphviz "
#     433         "(see instructions at https://graphviz.gitlab.io/download/) "
#     434         "for `plot_model` to work."
#     435     )
#     436     if "IPython.core.magics.namespace" in sys.modules:
#     437         # We don't raise an exception here in order to avoid crashing
#     438         # notebook tests where graphviz is not available.
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:39, in check_graphviz()
#      37     pydot.Dot.create(pydot.Dot())
#      38     return True
# ---> 39 except (OSError, pydot.InvocationException):
#      40     return False
#
# AttributeError: module 'pydot' has no attribute 'InvocationException'

# %%
def generate_latent_points(latent_dim, n):
    '''generate points in latent space as input for the generator'''
    x_input = np.random.rand(latent_dim*n) #generate points in latent space
    x_input = x_input.reshape(n,latent_dim)  #reshape
    return x_input

def generate_fake_samples(generator, latent_dim, n):
    x_input = generate_latent_points(latent_dim, n) #genarate points in latent space
    x = generator.predict(x_input) #predict outputs
    y = np.zeros((n, 1))
    return x, y

# %%
X, _ = generate_fake_samples(generator_model, latent_dim, 100)
plt.scatter(X[:,0], X[:,1])
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
def define_gan(generator, discriminator):
    '''define the combined generator and discriminator model'''
    discriminator.trainable = False
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy')
    return model

# %%
gan_model = define_gan(generator_model, discriminator_model)
gan_model.summary()
plot_model(gan_model, to_file = 'gan_model.png', show_layer_names = True, show_shapes = True)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)       │ (None, 2)              │           572 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 1)              │           551 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,123 (4.39 KB)
#  Trainable params: 572 (2.23 KB)
#  Non-trainable params: 551 (2.15 KB)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/pydot/core.py:1851, in Dot.create(self, prog, format, encoding)
#    1850 try:
# -> 1851     stdout_data, stderr_data, process = call_graphviz(
#    1852         program=prog,
#    1853         arguments=arguments,
#    1854         working_dir=tmp_dir,
#    1855     )
#    1856 except OSError as e:
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/pydot/core.py:211, in call_graphviz(program, arguments, working_dir, **kwargs)
#     209 program_with_args = [program] + arguments
# --> 211 process = subprocess.Popen(
#     212     program_with_args,
#     213     env=env,
#     214     cwd=working_dir,
#     215     shell=False,
#     216     stderr=subprocess.PIPE,
#     217     stdout=subprocess.PIPE,
#     218     **kwargs,
#     219 )
#     220 stdout_data, stderr_data = process.communicate()
#
# File /opt/anaconda3/envs/school/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /opt/anaconda3/envs/school/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:37, in check_graphviz()
#      34 try:
#      35     # Attempt to create an image of a blank graph
#      36     # to check the pydot/graphviz installation.
# ---> 37     pydot.Dot.create(pydot.Dot())
#      38     return True
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/pydot/core.py:1860, in Dot.create(self, prog, format, encoding)
#    1859     args[1] = f'"{prog}" not found in path.'
# -> 1860     raise OSError(*args)
#    1861 else:
#
# FileNotFoundError: [Errno 2] "dot" not found in path.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 gan_model = define_gan(generator_model, discriminator_model)
#       2 gan_model.summary()
# ----> 3 plot_model(gan_model, to_file = 'gan_model.png', show_layer_names = True, show_shapes = True)
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:430, in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, show_layer_activations, show_trainable, **kwargs)
#     428     else:
#     429         raise ImportError(message)
# --> 430 if not check_graphviz():
#     431     message = (
#     432         "You must install graphviz "
#     433         "(see instructions at https://graphviz.gitlab.io/download/) "
#     434         "for `plot_model` to work."
#     435     )
#     436     if "IPython.core.magics.namespace" in sys.modules:
#     437         # We don't raise an exception here in order to avoid crashing
#     438         # notebook tests where graphviz is not available.
#
# File /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:39, in check_graphviz()
#      37     pydot.Dot.create(pydot.Dot())
#      38     return True
# ---> 39 except (OSError, pydot.InvocationException):
#      40     return False
#
# AttributeError: module 'pydot' has no attribute 'InvocationException'

# %%
def train_gan(g_model,d_model,gan_model,latent_dim, num_epochs = 10000,num_eval = 2000, batch_size = 128):
    ''' function to train gan model'''
    half_batch = int(batch_size/2)
  #run epochs
    for i in range(num_epochs):
        X_real, y_real = generate_real_samples(half_batch) #generate real examples
        d_model.train_on_batch(X_real, y_real)               # train on real data
        X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch) #generate fake samples
        d_model.train_on_batch(X_fake, y_fake)                #train on fake data
        #prepare points in latent space as input for the generator
        x_gan = generate_latent_points(latent_dim, batch_size)
        y_gan = np.ones((batch_size, 1))    #generate fake labels for gan
        gan_model.train_on_batch(x_gan, y_gan)
        if (i+1) % num_eval == 0:
            summarize_performance(i + 1, g_model, d_model, latent_dim)

# %%
def summarize_performance(epoch, generator, discriminator, latent_dim, n = 100):
    '''evaluate the discriminator and plot real and fake samples'''
    x_real, y_real = generate_real_samples(n)      #generate real samples
    _, acc_real = discriminator.evaluate(x_real, y_real, verbose = 1)
    x_fake, y_fake = generate_fake_samples(generator, latent_dim, n)
    _, acc_fake = discriminator.evaluate(x_fake, y_fake, verbose = 1)
    print('Epoch: ' + str(epoch) + ' Real Acc.: ' + str(acc_real) + ' Fake Acc.: '+ str(acc_fake))
    plt.scatter(x_real[:,0], x_real[:,1], color = 'red')
    plt.scatter(x_fake[:,0], x_fake[:,1], color = 'blue')
    plt.show()

# %%
train_gan(generator_model, discriminator_model, gan_model, latent_dim)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# /opt/anaconda3/envs/school/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x1603aa520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x1603ab6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
